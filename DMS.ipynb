# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# C:\Users\anirudh\Desktop\misd\ddms\DDS_datset_640\DDMS.v2i.yolov8

# %%
#!pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.120  Python-3.8.16 torch-2.0.1+cpu CPU
# Setup complete  (8 CPUs, 7.9 GB RAM, 195.9/465.1 GB disk)

# %%
# !yolo task=detect mode=train model=r'Yolov8\yolov8n.pt' data=data.yaml epochs=100 batch=16 imgsz=640 plots=True pretrained=True seed=13
# Out:
# Ultralytics YOLOv8.0.20  Python-3.8.16 torch-2.0.0 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24564MiB)
# ...

# %%
# !yolo task=detect mode=predict model=r'C:\Users\anirudh\Desktop\misd\ddms\DDS_datset_640\DDMS.v2i.yolov8\runs\detect\train3\weights\best.pt' source=1 show=True imgsz=640 name=yolov8_test_video2 save=True
# Out:
# Ultralytics YOLOv8.0.120  Python-3.8.16 torch-2.0.1+cpu CPU
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients
#
# [ WARN:0@12.376] global cap_msmf.cpp:471 `anonymous-namespace'::SourceReaderCB::OnReadSample videoio(MSMF): OnReadSample() is called with error status: -1072875772
# [ WARN:0@12.376] global cap_msmf.cpp:483 `anonymous-namespace'::SourceReaderCB::OnReadSample videoio(MSMF): async ReadSample() call is failed with error status: -1072875772
# [ WARN:1@12.377] global cap_msmf.cpp:1759 CvCapture_MSMF::grabFrame videoio(MSMF): can't grab frame. Error: -1072875772
# Traceback (most recent call last):
#   File "C:\Users\anirudh\anaconda3\envs\torch\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\anirudh\anaconda3\envs\torch\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\anirudh\anaconda3\envs\torch\Scripts\yolo.exe\__main__.py", line 7, in <module>
# ...
